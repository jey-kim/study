# %%
#<img src="Figs/GEOS_Logo.png" width="700"/>

# %% [markdown]
# # Step **2** of **`G2FNL`**: <font color=blue>"preprocess_data.ipynb"</font>
# #### Aug 27, 2021  <font color=red>(v. 1.0.0)</font>
# ##### Jeonghyeop Kim (jeonghyeop.kim@gmail.com)
#
#
# > input files: **`GNSS data: STID.txt`** \
# > output files: **`u_%d`**
#
# 0. This code is a part of G2FNL process (Project1: GNSS to FNL)
# 1. This code preprocess the downloaded GNSS position data
#
# > **Remove header** \
# > **SAVE the following columns:**
# > time e n v se sn sv corr(e,n) network
#
# <div class="alert alert-danger">
# Do NOT run this code twice without re-starting the kernel
# </div>

# %%
import numpy as np
import pandas as pd
import os 

network_flag = 1
# This is for GNSS network index.
# If you don't jointly invert multiple GNSS networks, 
# This can be any integer.

# %%
current_dir = os.getcwd()
archive_dir = os.path.join(current_dir,'data', 'archive')
processing_dir = os.path.join(current_dir, 'data', 'processing')
os.getcwd()
# Out:
# '/Users/jkim/main/GPS2FNL_2021/summer_project_2021'

# %%
list_file='station_list_full.dat'
df_list=pd.read_csv(list_file ,header=None, names=['Sta'])
os.chdir(processing_dir) # cp to processing directory

# %%
os.environ["DATA_PATH"] = archive_dir
# !cp $DATA_PATH/*.txt .
for index, row in df_list.iterrows():
    
    data_file=row["Sta"]+".txt" # data file name
    output_num=index+1 
    output_name="u_"+str(output_num) # output file name
    
    #DataFrame does NOT read a header by its default
    df_data=pd.read_csv(data_file, sep=r'(?:,|\s+)', 
                            comment='#', engine='python') 
    
    #SAVE columns 
    df_data=df_data[['YYMMMDD','__east(m)','_north(m)','____up(m)', \
                 'sig_e(m)','sig_n(m)','sig_u(m)','__corr_en']]
    
    # Add network index
    df_data['flag']=np.array([1] * len(df_data))
    
    
    # SAVE file
    df_data.to_csv(output_name, header=None, \
                   index=None, sep=' ',float_format='%g')

# %%
os.chdir(processing_dir)
# make sure you are in 'processing directory'

# %%
# !ls
# Out:
# 7ODM.txt NVLM.txt P282.txt P618.txt u_100    u_283    u_465    u_647
# ACSB.txt NVPO.txt P283.txt P619.txt u_101    u_284    u_466    u_648
# ACSX.txt OAES.txt P284.txt P620.txt u_102    u_285    u_467    u_649
# AGMT.txt OCSD.txt P285.txt P621.txt u_103    u_286    u_468    u_65
# ALAM.txt OPBL.txt P286.txt P622.txt u_104    u_287    u_469    u_650
# ALTH.txt OPCL.txt P287.txt P623.txt u_105    u_288    u_47     u_651
# ANA1.txt OPCP.txt P288.txt P625.txt u_106    u_289    u_470    u_652
# AR27.txt OPCX.txt P289.txt P626.txt u_107    u_29     u_471    u_653
# AR53.txt OPRD.txt P290.txt P627.txt u_108    u_290    u_472    u_654
# AVRY.txt ORES.txt P291.txt P628.txt u_109    u_291    u_473    u_655
# AZRY.txt ORMT.txt P293.txt P629.txt u_11     u_292    u_474    u_656
# AZU1.txt ORVB.txt P294.txt P630.txt u_110    u_293    u_475    u_657
# BALD.txt OVLS.txt P295.txt P631.txt u_111    u_294    u_476    u_658
# BAMO.txt OXMT.txt P298.txt P632.txt u_112    u_295    u_477    u_659
# BAR1.txt OZST.txt P300.txt P633.txt u_113    u_296    u_478    u_66
# BBDM.txt P002.txt P302.txt P634.txt u_114    u_297    u_479    u_660
# BBRY.txt P003.txt P303.txt P635.txt u_115    u_298    u_48     u_661
# BCWR.txt P005.txt P304.txt P636.txt u_116    u_299    u_480    u_662
# BEMT.txt P006.txt P305.txt P637.txt u_117    u_3      u_481    u_663
# BEPK.txt P007.txt P306.txt P638.txt u_118    u_30     u_482    u_664
# BGIS.txt P010.txt P307.txt P639.txt u_119    u_300    u_483    u_665
# BILL.txt P013.txt P308.txt P640.txt u_12     u_301    u_484    u_666
# BKAP.txt P017.txt P309.txt P641.txt u_120    u_302    u_485    u_667
# BKMS.txt P018.txt P310.txt P642.txt u_121    u_303    u_486    u_668
# BLYT.txt P056.txt P311.txt P643.txt u_122    u_304    u_487    u_669
# BMHL.txt P058.txt P312.txt P644.txt u_123    u_305    u_488    u_67
# BOMG.txt P059.txt P314.txt P645.txt u_124    u_306    u_489    u_670
# BRAN.txt P060.txt P315.txt P646.txt u_125    u_307    u_49     u_671
# BSRY.txt P066.txt P316.txt P647.txt u_126    u_308    u_490    u_672
# BTDM.txt P067.txt P317.txt P648.txt u_127    u_309    u_491    u_673
# BUEG.txt P068.txt P318.txt P649.txt u_128    u_31     u_492    u_674
# BURN.txt P069.txt P319.txt P650.txt u_129    u_310    u_493    u_675
# BVPP.txt P071.txt P320.txt P651.txt u_13     u_311    u_494    u_676
# CA99.txt P072.txt P321.txt P652.txt u_130    u_312    u_495    u_677
# CABL.txt P073.txt P322.txt P653.txt u_131    u_313    u_496    u_678
# CACT.txt P074.txt P324.txt P654.txt u_132    u_314    u_497    u_679
# CASE.txt P075.txt P325.txt P656.txt u_133    u_315    u_498    u_68
# CAT2.txt P076.txt P326.txt P657.txt u_134    u_316    u_499    u_680
# CAT3.txt P077.txt P327.txt P659.txt u_135    u_317    u_5      u_681
# CBHS.txt P078.txt P332.txt P669.txt u_136    u_318    u_50     u_682
# CCCC.txt P080.txt P335.txt P677.txt u_137    u_319    u_500    u_683
# CDMT.txt P081.txt P336.txt P723.txt u_138    u_32     u_501    u_684
# CGDM.txt P083.txt P337.txt P724.txt u_139    u_320    u_502    u_685
# CHIL.txt P084.txt P338.txt P725.txt u_14     u_321    u_503    u_686
# CHMS.txt P085.txt P339.txt P726.txt u_140    u_322    u_504    u_687
# CHOW.txt P087.txt P341.txt P727.txt u_141    u_323    u_505    u_688
# CIRX.txt P090.txt P343.txt P729.txt u_142    u_324    u_506    u_689
# CIT1.txt P091.txt P344.txt P730.txt u_143    u_325    u_507    u_69
# CJMS.txt P092.txt P345.txt P731.txt u_144    u_326    u_508    u_690
# CJVG.txt P093.txt P346.txt P733.txt u_145    u_327    u_509    u_691
# CLAR.txt P094.txt P347.txt P734.txt u_146    u_328    u_51     u_692
# CLBD.txt P095.txt P349.txt P735.txt u_147    u_329    u_510    u_693
# CLCV.txt P096.txt P362.txt P736.txt u_148    u_33     u_511    u_694
# CLHQ.txt P097.txt P368.txt P738.txt u_149    u_330    u_512    u_695
# CLMS.txt P098.txt P370.txt P739.txt u_15     u_331    u_513    u_696
# CLWZ.txt P099.txt P380.txt P740.txt u_150    u_332    u_514    u_697
# CMBB.txt P100.txt P388.txt P741.txt u_151    u_333    u_515    u_698
# CMOD.txt P102.txt P391.txt P742.txt u_152    u_334    u_516    u_699
# CMP9.txt P111.txt P463.txt P744.txt u_153    u_335    u_517    u_7
# CNPP.txt P113.txt P464.txt P784.txt u_154    u_336    u_518    u_70
# COAG.txt P127.txt P465.txt P786.txt u_155    u_337    u_519    u_700
# COPR.txt P128.txt P466.txt P787.txt u_156    u_338    u_52     u_701
# COSO.txt P129.txt P467.txt P788.txt u_157    u_339    u_520    u_702
# COTD.txt P130.txt P468.txt P789.txt u_158    u_34     u_521    u_703
# CPBN.txt P131.txt P469.txt P793.txt u_159    u_340    u_522    u_704
# CRBT.txt P132.txt P470.txt P794.txt u_16     u_341    u_523    u_705
# CRCN.txt P133.txt P471.txt P796.txt u_160    u_342    u_524    u_706
# CRFP.txt P134.txt P472.txt P797.txt u_161    u_343    u_525    u_707
# CRGG.txt P135.txt P473.txt P799.txt u_162    u_344    u_526    u_708
# CRRS.txt P136.txt P474.txt P800.txt u_163    u_345    u_527    u_709
# CRU1.txt P137.txt P475.txt P808.txt u_164    u_346    u_528    u_71
# CSCI.txt P138.txt P476.txt P809.txt u_165    u_347    u_529    u_710
# CSDH.txt P139.txt P477.txt P810.txt u_166    u_348    u_53     u_711
# CSN1.txt P140.txt P478.txt P811.txt u_167    u_349    u_530    u_712
# CSST.txt P142.txt P479.txt P812.txt u_168    u_35     u_531    u_713
# CTDM.txt P143.txt P480.txt P820.txt u_169    u_350    u_532    u_714
# CTMS.txt P144.txt P481.txt PALX.txt u_17     u_351    u_533    u_715
# CUHS.txt P145.txt P482.txt PB1Y.txt u_170    u_352    u_534    u_716
# CVHS.txt P146.txt P483.txt PBPP.txt u_171    u_353    u_535    u_717
# DAM2.txt P147.txt P484.txt PEA1.txt u_172    u_354    u_536    u_718
# DDMN.txt P148.txt P485.txt PEA2.txt u_173    u_355    u_537    u_719
# DECH.txt P149.txt P486.txt PIN1.txt u_174    u_356    u_538    u_72
# DHLG.txt P150.txt P487.txt PJZX.txt u_175    u_357    u_539    u_720
# DIAB.txt P151.txt P488.txt PKDB.txt u_176    u_358    u_54     u_721
# DIXN.txt P154.txt P489.txt PKRD.txt u_177    u_359    u_540    u_722
# DLUZ.txt P155.txt P490.txt PLPX.txt u_178    u_36     u_541    u_723
# DOND.txt P156.txt P491.txt PLTX.txt u_179    u_360    u_542    u_724
# DSME.txt P157.txt P492.txt PMTN.txt u_18     u_361    u_543    u_725
# DSSC.txt P158.txt P493.txt POBG.txt u_180    u_362    u_544    u_726
# DTPG.txt P159.txt P494.txt PPBF.txt u_181    u_363    u_545    u_727
# DYH2.txt P160.txt P495.txt PSDM.txt u_182    u_364    u_546    u_728
# EBMD.txt P161.txt P496.txt PSPT.txt u_183    u_365    u_547    u_729
# ECFS.txt P162.txt P497.txt PTEX.txt u_184    u_366    u_548    u_73
# ECHO.txt P163.txt P498.txt PTSG.txt u_185    u_367    u_549    u_730
# EDPP.txt P164.txt P499.txt PVE3.txt u_186    u_368    u_55     u_731
# EGAN.txt P165.txt P500.txt PVHS.txt u_187    u_369    u_550    u_732
# ELKO.txt P167.txt P501.txt PVRS.txt u_188    u_37     u_551    u_733
# ELLY.txt P168.txt P502.txt QCY2.txt u_189    u_370    u_552    u_734
# ELSC.txt P169.txt P503.txt QHTP.txt u_19     u_371    u_553    u_735
# ELSG.txt P170.txt P504.txt QUEX.txt u_190    u_372    u_554    u_736
# ELTN.txt P171.txt P505.txt QUIN.txt u_191    u_373    u_555    u_737
# EOCG.txt P172.txt P506.txt RAMT.txt u_192    u_374    u_556    u_738
# ERRG.txt P173.txt P507.txt RAPT.txt u_193    u_375    u_557    u_739
# EWPP.txt P174.txt P508.txt RBRU.txt u_194    u_376    u_558    u_74
# FARB.txt P175.txt P509.txt RCA2.txt u_195    u_377    u_559    u_740
# FGST.txt P176.txt P510.txt RCSC.txt u_196    u_378    u_56     u_741
# FHOG.txt P177.txt P511.txt RDMT.txt u_197    u_379    u_560    u_742
# FMTP.txt P178.txt P512.txt RDOM.txt u_198    u_38     u_561    u_743
# FMVT.txt P179.txt P513.txt RHCG.txt u_199    u_380    u_562    u_744
# FOOT.txt P180.txt P514.txt RHCL.txt u_2      u_381    u_563    u_745
# FSHB.txt P181.txt P515.txt RKMG.txt u_20     u_382    u_564    u_746
# FZHS.txt P182.txt P516.txt RMVJ.txt u_200    u_383    u_565    u_747
# GARL.txt P183.txt P517.txt RNCH.txt u_201    u_384    u_566    u_748
# GDEC.txt P184.txt P518.txt ROCK.txt u_202    u_385    u_567    u_749
# GHRP.txt P185.txt P519.txt RSTP.txt u_203    u_386    u_568    u_75
# GLRS.txt P186.txt P520.txt RSVY.txt u_204    u_387    u_569    u_750
# GMAG.txt P187.txt P521.txt RTHS.txt u_205    u_388    u_57     u_751
# GMPK.txt P188.txt P522.txt RUBY.txt u_206    u_389    u_570    u_752
# GMRC.txt P189.txt P523.txt RUNG.txt u_207    u_39     u_571    u_753
# GNPS.txt P190.txt P525.txt S300.txt u_208    u_390    u_572    u_754
# GOL2.txt P191.txt P526.txt SAOB.txt u_209    u_391    u_573    u_755
# GOLD.txt P192.txt P527.txt SAWC.txt u_21     u_392    u_574    u_756
# GOSH.txt P193.txt P528.txt SBCC.txt u_210    u_393    u_575    u_757
# GTPS.txt P194.txt P529.txt SBRB.txt u_211    u_394    u_576    u_758
# GVRS.txt P195.txt P530.txt SCCP.txt u_212    u_395    u_577    u_759
# HAR7.txt P196.txt P531.txt SCIA.txt u_213    u_396    u_578    u_76
# HBCO.txt P197.txt P532.txt SDHL.txt u_214    u_397    u_579    u_760
# HCMN.txt P198.txt P533.txt SFDM.txt u_215    u_398    u_58     u_761
# HCRO.txt P199.txt P534.txt SGPS.txt u_216    u_399    u_580    u_762
# HIVI.txt P200.txt P535.txt SGU1.txt u_217    u_4      u_581    u_763
# HMTG.txt P201.txt P536.txt SHIN.txt u_218    u_40     u_582    u_764
# HNPS.txt P202.txt P537.txt SHLD.txt u_219    u_400    u_583    u_765
# HOLP.txt P203.txt P538.txt SHOS.txt u_22     u_401    u_584    u_766
# HOPB.txt P204.txt P539.txt SHRC.txt u_220    u_402    u_585    u_767
# HOTK.txt P205.txt P540.txt SILK.txt u_221    u_403    u_586    u_768
# HVYS.txt P206.txt P541.txt SKYB.txt u_222    u_404    u_587    u_769
# I40A.txt P207.txt P542.txt SLAC.txt u_223    u_405    u_588    u_77
# IDOG.txt P208.txt P543.txt SLHG.txt u_224    u_406    u_589    u_770
# IDQG.txt P209.txt P544.txt SLID.txt u_225    u_407    u_59     u_771
# IID2.txt P210.txt P545.txt SLMS.txt u_226    u_408    u_590    u_772
# IMPS.txt P211.txt P548.txt SOMT.txt u_227    u_409    u_591    u_773
# ISLK.txt P212.txt P550.txt SONG.txt u_228    u_41     u_592    u_774
# JNHG.txt P213.txt P551.txt SPMS.txt u_229    u_410    u_593    u_775
# JPLM.txt P214.txt P552.txt SRB1.txt u_23     u_411    u_594    u_776
# JRSC.txt P215.txt P553.txt SRS1.txt u_230    u_412    u_595    u_777
# KBRC.txt P216.txt P554.txt SUTB.txt u_231    u_413    u_596    u_778
# KFRC.txt P217.txt P555.txt SVIN.txt u_232    u_414    u_597    u_779
# KNOL.txt P219.txt P556.txt SYNG.txt u_233    u_415    u_598    u_78
# KRAC.txt P220.txt P557.txt T3RP.txt u_234    u_416    u_599    u_780
# KYVW.txt P221.txt P558.txt TABL.txt u_235    u_417    u_6      u_781
# LAPC.txt P222.txt P560.txt TEHA.txt u_236    u_418    u_60     u_782
# LBC1.txt P223.txt P561.txt THCP.txt u_237    u_419    u_600    u_783
# LBC2.txt P224.txt P563.txt THMG.txt u_238    u_42     u_601    u_784
# LBCH.txt P225.txt P564.txt TIBB.txt u_239    u_420    u_602    u_785
# LDES.txt P226.txt P565.txt TILC.txt u_24     u_421    u_603    u_786
# LDSW.txt P227.txt P566.txt TIVA.txt u_240    u_422    u_604    u_787
# LEMA.txt P228.txt P567.txt TJRN.txt u_241    u_423    u_605    u_788
# LEWI.txt P229.txt P568.txt TMAP.txt u_242    u_424    u_606    u_789
# LFRS.txt P230.txt P569.txt TNPP.txt u_243    u_425    u_607    u_79
# LGWD.txt P231.txt P570.txt TOIY.txt u_244    u_426    u_608    u_790
# LINC.txt P232.txt P571.txt TONO.txt u_245    u_427    u_609    u_791
# LINJ.txt P233.txt P572.txt TORP.txt u_246    u_428    u_61     u_792
# LJRN.txt P234.txt P574.txt TOST.txt u_247    u_429    u_610    u_793
# LKHG.txt P235.txt P575.txt TPOG.txt u_248    u_43     u_611    u_794
# LLAS.txt P237.txt P576.txt TRAK.txt u_249    u_430    u_612    u_795
# LMHG.txt P239.txt P577.txt TRCP.txt u_25     u_431    u_613    u_796
# LNMT.txt P241.txt P578.txt TRND.txt u_250    u_432    u_614    u_797
# LOMP.txt P242.txt P579.txt TUNG.txt u_251    u_433    u_615    u_798
# LONG.txt P243.txt P580.txt UCSF.txt u_252    u_434    u_616    u_799
# LORS.txt P244.txt P581.txt UPSA.txt u_253    u_435    u_617    u_8
# LPHS.txt P245.txt P582.txt USGC.txt u_254    u_436    u_618    u_80
# LRRG.txt P247.txt P583.txt USLO.txt u_255    u_437    u_619    u_800
# LUTZ.txt P248.txt P584.txt VCVL.txt u_256    u_438    u_62     u_801
# LVMS.txt P249.txt P585.txt VDCY.txt u_257    u_439    u_620    u_802
# MAT2.txt P250.txt P586.txt VIMT.txt u_258    u_44     u_621    u_803
# MDMT.txt P251.txt P587.txt VNCO.txt u_259    u_440    u_622    u_804
# MERC.txt P252.txt P589.txt VNCX.txt u_26     u_441    u_623    u_805
# MHCB.txt P253.txt P590.txt VNDP.txt u_260    u_442    u_624    u_81
# MHDL.txt P255.txt P591.txt VNPS.txt u_261    u_443    u_625    u_82
# MHMS.txt P256.txt P592.txt VTOR.txt u_262    u_444    u_626    u_83
# MIG1.txt P257.txt P593.txt WASG.txt u_263    u_445    u_627    u_84
# MILK.txt P258.txt P594.txt WATC.txt u_264    u_446    u_628    u_85
# MILP.txt P261.txt P595.txt WCHS.txt u_265    u_447    u_629    u_86
# MINE.txt P262.txt P596.txt WGPP.txt u_266    u_448    u_63     u_87
# MINS.txt P263.txt P597.txt WHC1.txt u_267    u_449    u_630    u_88
# MJPK.txt P264.txt P598.txt WHFG.txt u_268    u_45     u_631    u_89
# MLFP.txt P265.txt P599.txt WIDC.txt u_269    u_450    u_632    u_9
# MODB.txt P266.txt P600.txt WIN2.txt u_27     u_451    u_633    u_90
# MONB.txt P267.txt P602.txt WINT.txt u_270    u_452    u_634    u_91
# MONP.txt P268.txt P603.txt WKPK.txt u_271    u_453    u_635    u_92
# MPWD.txt P269.txt P604.txt WMAP.txt u_272    u_454    u_636    u_93
# MSOB.txt P270.txt P605.txt WNRA.txt u_273    u_455    u_637    u_94
# MTGG.txt P271.txt P606.txt WOMT.txt u_274    u_456    u_638    u_95
# MULN.txt P272.txt P607.txt WORG.txt u_275    u_457    u_639    u_96
# MUSB.txt P274.txt P608.txt WRHS.txt u_276    u_458    u_64     u_97
# MWTP.txt P275.txt P610.txt YBHB.txt u_277    u_459    u_640    u_98
# NDAP.txt P276.txt P611.txt YUHG.txt u_278    u_46     u_641    u_99
# NEWS.txt P277.txt P612.txt YUMX.txt u_279    u_460    u_642
# NHRG.txt P278.txt P613.txt ZLA1.txt u_28     u_461    u_643
# NOCO.txt P279.txt P614.txt ZOA1.txt u_280    u_462    u_644
# NOPK.txt P280.txt P616.txt u_1      u_281    u_463    u_645
# NVBM.txt P281.txt P617.txt u_10     u_282    u_464    u_646

# %%
# !ls

# %%
os.chdir(current_dir)
